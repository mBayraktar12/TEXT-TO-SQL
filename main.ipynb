# %%
from vanna.openai import OpenAI_Chat
from vanna.chromadb import ChromaDB_VectorStore

# %%
import json
import openai

# Load the config file
with open("config.json", "r") as config_file:
    config = json.load(config_file)

# Retrieve and set the API key
openai.api_key = config.get("OPENAI_API_KEY")
postgres_password = config.get("POSTGRES_PASSWORD")
if not openai.api_key:
    raise ValueError("OPENAI_API_KEY is not set in config.json!")

# %%
pair_format = {
    "question": "what are daily averages for max battery power and min battery power differences for each Imei?",
    "sql": 'SELECT "Imei", AVG(Daily_Diff_Battery_Power) AS Daily_Avg_Diff_Battery_Power FROM (SELECT "Imei", DATE("Timestamp") AS Date MAX("BMS_UBatt") - MIN("BMS_UBatt") AS Daily_Diff_Battery_Power FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei", Date) AS DailyDiffs GROUP BY "Imei";'}

column_names = [
    "LastModifiedOn""Id""Latitude""Longitude""BMS_IBatt""BMS_UBatt""BMS_UserSOC""BMS_InternalSOC""BMS_UCellAvg""BMS_UCellMax""BMS_UCellMin""BMS_CellTMax""BMS_CellTMin""BMS_SOCRecalibState""Timestamp""CreatedBy""CreatedOn""LastModifiedBy""Imei"
]


class MyVanna(ChromaDB_VectorStore, OpenAI_Chat):
    def __init__(self, config=None):
        ChromaDB_VectorStore.__init__(self, config=config)
        OpenAI_Chat.__init__(self, config=config)
    
    def generate_queries(self, sql: str):
        my_prompt = [
            self.system_message(f"You are a helpful assistant that will generate advanced question sql pairs using column names: {column_names} with following format: {pair_format}"),
            self.user_message("Create queries based on the information schema and tables you have.")
        ]

        return self.submit_prompt(prompt = my_prompt)

vn = MyVanna(config={
    'api_key': openai.api_key,
    'model': 'gpt-4'
})

# %%
vn.connect_to_postgres(host='localhost',
                        dbname='devicetelemetry',
                        user='postgres', 
                        password=postgres_password,
                        port='5432')

# %%
df_information_schema = vn.run_sql("SELECT * FROM INFORMATION_SCHEMA.COLUMNS")

# %%
df_information_schema
# Out:
#         table_catalog        table_schema               table_name  \
# 0     devicetelemetry          pg_catalog             pg_collation
# 1     devicetelemetry          pg_catalog                  pg_amop
# 2     devicetelemetry          pg_catalog                  pg_amop
# 3     devicetelemetry          pg_catalog                  pg_amop
# 4     devicetelemetry          pg_catalog                  pg_amop
# ...               ...                 ...                      ...
# 2087  devicetelemetry  information_schema                 routines
# 2088  devicetelemetry          pg_catalog  pg_statio_all_sequences
# 2089  devicetelemetry          pg_catalog  pg_statio_all_sequences
# 2090  devicetelemetry  information_schema                 routines
# 2091  devicetelemetry  information_schema                 routines
#
#             column_name  ordinal_position column_default is_nullable  \
# 0          collencoding                 7           None          NO
# 1          amoplefttype                 3           None          NO
# 2         amoprighttype                 4           None          NO
# 3          amopstrategy                 5           None          NO
# 4           amoppurpose                 6           None          NO
# ...                 ...               ...            ...         ...
# 2087  external_language                40           None         YES
# 2088         schemaname                 2           None         YES
# 2089            relname                 3           None         YES
# 2090    parameter_style                41           None         YES
# 2091   is_deterministic                42           None         YES
#
#               data_type  character_maximum_length  character_octet_length  \
# 0               integer                       NaN                     NaN
# 1                   oid                       NaN                     NaN
# 2                   oid                       NaN                     NaN
# 3              smallint                       NaN                     NaN
# 4                "char"                       NaN                     NaN
# ...                 ...                       ...                     ...
# 2087  character varying                       NaN            1.073742e+09
# 2088               name                       NaN                     NaN
# 2089               name                       NaN                     NaN
# 2090  character varying                       NaN            1.073742e+09
# 2091  character varying                       3.0            1.200000e+01
#
#       ...  is_identity  identity_generation  identity_start  \
# 0     ...           NO                 None            None
# 1     ...           NO                 None            None
# 2     ...           NO                 None            None
# 3     ...           NO                 None            None
# 4     ...           NO                 None            None
# ...   ...          ...                  ...             ...
# 2087  ...           NO                 None            None
# 2088  ...           NO                 None            None
# 2089  ...           NO                 None            None
# 2090  ...           NO                 None            None
# 2091  ...           NO                 None            None
#
#       identity_increment identity_maximum identity_minimum identity_cycle  \
# 0                   None             None             None             NO
# 1                   None             None             None             NO
# 2                   None             None             None             NO
# 3                   None             None             None             NO
# 4                   None             None             None             NO
# ...                  ...              ...              ...            ...
# 2087                None             None             None             NO
# 2088                None             None             None             NO
# 2089                None             None             None             NO
# 2090                None             None             None             NO
# 2091                None             None             None             NO
#
#      is_generated generation_expression is_updatable
# 0           NEVER                  None          YES
# 1           NEVER                  None          YES
# 2           NEVER                  None          YES
# 3           NEVER                  None          YES
# 4           NEVER                  None          YES
# ...           ...                   ...          ...
# 2087        NEVER                  None           NO
# 2088        NEVER                  None           NO
# 2089        NEVER                  None           NO
# 2090        NEVER                  None           NO
# 2091        NEVER                  None           NO
#
# [2092 rows x 44 columns]

# %%
plan = vn.get_training_plan_generic(df_information_schema)
plan
# Out:
# Train on Information Schema: devicetelemetry.pg_catalog pg_collation
# Train on Information Schema: devicetelemetry.pg_catalog pg_amop
# Train on Information Schema: devicetelemetry.pg_catalog pg_amproc
# Train on Information Schema: devicetelemetry.pg_catalog pg_language
# Train on Information Schema: devicetelemetry.pg_catalog pg_largeobject_metadata
# Train on Information Schema: devicetelemetry.pg_catalog pg_largeobject
# Train on Information Schema: devicetelemetry.pg_catalog pg_aggregate
# Train on Information Schema: devicetelemetry.pg_catalog pg_statistic
# Train on Information Schema: devicetelemetry.pg_catalog pg_statistic_ext
# Train on Information Schema: devicetelemetry.pg_catalog pg_statistic_ext_data
# Train on Information Schema: devicetelemetry.pg_catalog pg_rewrite
# Train on Information Schema: devicetelemetry.pg_catalog pg_trigger
# Train on Information Schema: devicetelemetry.pg_catalog pg_event_trigger
# Train on Information Schema: devicetelemetry.pg_catalog pg_description
# Train on Information Schema: devicetelemetry.pg_catalog pg_cast
# Train on Information Schema: devicetelemetry.pg_catalog pg_enum
# Train on Information Schema: devicetelemetry.pg_catalog pg_namespace
# Train on Information Schema: devicetelemetry.pg_catalog pg_conversion
# Train on Information Schema: devicetelemetry.pg_catalog pg_depend
# Train on Information Schema: devicetelemetry.pg_catalog pg_database
# Train on Information Schema: devicetelemetry.pg_catalog pg_db_role_setting
# Train on Information Schema: devicetelemetry.pg_catalog pg_tablespace
# Train on Information Schema: devicetelemetry.pg_catalog pg_authid
# Train on Information Schema: devicetelemetry.pg_catalog pg_auth_members
# Train on Information Schema: devicetelemetry.pg_catalog pg_shdepend
# Train on Information Schema: devicetelemetry.pg_catalog pg_shdescription
# Train on Information Schema: devicetelemetry.pg_catalog pg_ts_config
# Train on Information Schema: devicetelemetry.pg_catalog pg_ts_config_map
# Train on Information Schema: devicetelemetry.pg_catalog pg_ts_dict
# Train on Information Schema: devicetelemetry.pg_catalog pg_ts_parser
# Train on Information Schema: devicetelemetry.pg_catalog pg_ts_template
# Train on Information Schema: devicetelemetry.pg_catalog pg_extension
# Train on Information Schema: devicetelemetry.pg_catalog pg_foreign_data_wrapper
# Train on Information Schema: devicetelemetry.pg_catalog pg_foreign_server
# Train on Information Schema: devicetelemetry.pg_catalog pg_user_mapping
# Train on Information Schema: devicetelemetry.pg_catalog pg_foreign_table
# Train on Information Schema: devicetelemetry.pg_catalog pg_policy
# Train on Information Schema: devicetelemetry.pg_catalog pg_replication_origin
# Train on Information Schema: devicetelemetry.pg_catalog pg_default_acl
# Train on Information Schema: devicetelemetry.pg_catalog pg_init_privs
# Train on Information Schema: devicetelemetry.pg_catalog pg_seclabel
# Train on Information Schema: devicetelemetry.pg_catalog pg_shseclabel
# Train on Information Schema: devicetelemetry.pg_catalog pg_proc
# Train on Information Schema: devicetelemetry.pg_catalog pg_parameter_acl
# Train on Information Schema: devicetelemetry.pg_catalog pg_partitioned_table
# Train on Information Schema: devicetelemetry.pg_catalog pg_range
# Train on Information Schema: devicetelemetry.pg_catalog pg_transform
# Train on Information Schema: devicetelemetry.pg_catalog pg_sequence
# Train on Information Schema: devicetelemetry.pg_catalog pg_publication
# Train on Information Schema: devicetelemetry.pg_catalog pg_publication_namespace
# Train on Information Schema: devicetelemetry.pg_catalog pg_publication_rel
# Train on Information Schema: devicetelemetry.pg_catalog pg_subscription_rel
# Train on Information Schema: devicetelemetry.pg_catalog pg_roles
# Train on Information Schema: devicetelemetry.pg_catalog pg_shadow
# Train on Information Schema: devicetelemetry.pg_catalog pg_group
# Train on Information Schema: devicetelemetry.pg_catalog pg_user
# Train on Information Schema: devicetelemetry.pg_catalog pg_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_matviews
# Train on Information Schema: devicetelemetry.pg_catalog pg_sequences
# Train on Information Schema: devicetelemetry.pg_catalog pg_stats
# Train on Information Schema: devicetelemetry.pg_catalog pg_stats_ext
# Train on Information Schema: devicetelemetry.pg_catalog pg_stats_ext_exprs
# Train on Information Schema: devicetelemetry.pg_catalog pg_locks
# Train on Information Schema: devicetelemetry.pg_catalog pg_cursors
# Train on Information Schema: devicetelemetry.pg_catalog pg_available_extension_versions
# Train on Information Schema: devicetelemetry.pg_catalog pg_prepared_xacts
# Train on Information Schema: devicetelemetry.pg_catalog pg_prepared_statements
# Train on Information Schema: devicetelemetry.pg_catalog pg_seclabels
# Train on Information Schema: devicetelemetry.pg_catalog pg_settings
# Train on Information Schema: devicetelemetry.pg_catalog pg_file_settings
# Train on Information Schema: devicetelemetry.pg_catalog pg_hba_file_rules
# Train on Information Schema: devicetelemetry.pg_catalog pg_ident_file_mappings
# Train on Information Schema: devicetelemetry.pg_catalog pg_timezone_abbrevs
# Train on Information Schema: devicetelemetry.pg_catalog pg_timezone_names
# Train on Information Schema: devicetelemetry.pg_catalog pg_shmem_allocations
# Train on Information Schema: devicetelemetry.pg_catalog pg_backend_memory_contexts
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_all_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_xact_all_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_sys_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_xact_sys_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_user_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_xact_user_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_all_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_sys_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_user_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_all_indexes
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_sys_indexes
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_user_indexes
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_all_indexes
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_sys_indexes
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_user_indexes
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_all_sequences
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_sys_sequences
# Train on Information Schema: devicetelemetry.pg_catalog pg_statio_user_sequences
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_activity
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_replication
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_slru
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_wal_receiver
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_recovery_prefetch
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_subscription
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_ssl
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_gssapi
# Train on Information Schema: devicetelemetry.pg_catalog pg_replication_slots
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_replication_slots
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_database
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_database_conflicts
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_user_functions
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_xact_user_functions
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_archiver
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_bgwriter
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_checkpointer
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_io
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_wal
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_progress_analyze
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_progress_vacuum
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_progress_cluster
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_progress_create_index
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_progress_basebackup
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_progress_copy
# Train on Information Schema: devicetelemetry.pg_catalog pg_user_mappings
# Train on Information Schema: devicetelemetry.pg_catalog pg_replication_origin_status
# Train on Information Schema: devicetelemetry.pg_catalog pg_subscription
# Train on Information Schema: devicetelemetry.pg_catalog pg_stat_subscription_stats
# Train on Information Schema: devicetelemetry.pg_catalog pg_type
# Train on Information Schema: devicetelemetry.pg_catalog pg_attribute
# Train on Information Schema: devicetelemetry.pg_catalog pg_class
# Train on Information Schema: devicetelemetry.pg_catalog pg_attrdef
# Train on Information Schema: devicetelemetry.pg_catalog pg_constraint
# Train on Information Schema: devicetelemetry.pg_catalog pg_inherits
# Train on Information Schema: devicetelemetry.pg_catalog pg_index
# Train on Information Schema: devicetelemetry.pg_catalog pg_operator
# Train on Information Schema: devicetelemetry.pg_catalog pg_opfamily
# Train on Information Schema: devicetelemetry.pg_catalog pg_opclass
# Train on Information Schema: devicetelemetry.pg_catalog pg_am
# Train on Information Schema: devicetelemetry.pg_catalog pg_publication_tables
# Train on Information Schema: devicetelemetry.pg_catalog pg_policies
# Train on Information Schema: devicetelemetry.pg_catalog pg_available_extensions
# Train on Information Schema: devicetelemetry.pg_catalog pg_rules
# Train on Information Schema: devicetelemetry.pg_catalog pg_views
# Train on Information Schema: devicetelemetry.pg_catalog pg_wait_events
# Train on Information Schema: devicetelemetry.pg_catalog pg_indexes
# Train on Information Schema: devicetelemetry.pg_catalog pg_config
# Train on Information Schema: devicetelemetry.Catalog DeviceTelemetryData
# Train on Information Schema: devicetelemetry.information_schema attributes
# Train on Information Schema: devicetelemetry.information_schema columns
# Train on Information Schema: devicetelemetry.information_schema domains
# Train on Information Schema: devicetelemetry.information_schema key_column_usage
# Train on Information Schema: devicetelemetry.information_schema parameters
# Train on Information Schema: devicetelemetry.information_schema routines
# Train on Information Schema: devicetelemetry.information_schema sequences
# Train on Information Schema: devicetelemetry.information_schema sql_implementation_info
# Train on Information Schema: devicetelemetry.information_schema sql_sizing
# Train on Information Schema: devicetelemetry.information_schema triggers
# Train on Information Schema: devicetelemetry.information_schema user_defined_types
# Train on Information Schema: devicetelemetry.information_schema element_types
# Train on Information Schema: devicetelemetry.information_schema _pg_foreign_data_wrappers
# Train on Information Schema: devicetelemetry.information_schema _pg_foreign_servers
# Train on Information Schema: devicetelemetry.information_schema _pg_user_mappings
# Train on Information Schema: devicetelemetry.information_schema foreign_servers
# Train on Information Schema: devicetelemetry.information_schema _pg_foreign_tables
# Train on Information Schema: devicetelemetry.information_schema schemata
# Train on Information Schema: devicetelemetry.information_schema sql_features
# Train on Information Schema: devicetelemetry.information_schema foreign_table_options
# Train on Information Schema: devicetelemetry.information_schema sql_parts
# Train on Information Schema: devicetelemetry.information_schema table_constraints
# Train on Information Schema: devicetelemetry.information_schema table_privileges
# Train on Information Schema: devicetelemetry.information_schema role_table_grants
# Train on Information Schema: devicetelemetry.information_schema tables
# Train on Information Schema: devicetelemetry.information_schema transforms
# Train on Information Schema: devicetelemetry.information_schema triggered_update_columns
# Train on Information Schema: devicetelemetry.information_schema udt_privileges
# Train on Information Schema: devicetelemetry.information_schema role_udt_grants
# Train on Information Schema: devicetelemetry.information_schema usage_privileges
# Train on Information Schema: devicetelemetry.information_schema role_usage_grants
# Train on Information Schema: devicetelemetry.information_schema foreign_tables
# Train on Information Schema: devicetelemetry.information_schema user_mappings
# Train on Information Schema: devicetelemetry.information_schema view_column_usage
# Train on Information Schema: devicetelemetry.information_schema view_routine_usage
# Train on Information Schema: devicetelemetry.information_schema view_table_usage
# Train on Information Schema: devicetelemetry.information_schema views
# Train on Information Schema: devicetelemetry.information_schema data_type_privileges
# Train on Information Schema: devicetelemetry.information_schema user_mapping_options
# Train on Information Schema: devicetelemetry.information_schema information_schema_catalog_name
# Train on Information Schema: devicetelemetry.information_schema applicable_roles
# Train on Information Schema: devicetelemetry.information_schema administrable_role_authorizations
# Train on Information Schema: devicetelemetry.information_schema _pg_foreign_table_columns
# Train on Information Schema: devicetelemetry.information_schema character_sets
# Train on Information Schema: devicetelemetry.information_schema check_constraint_routine_usage
# Train on Information Schema: devicetelemetry.information_schema check_constraints
# Train on Information Schema: devicetelemetry.information_schema collations
# Train on Information Schema: devicetelemetry.information_schema collation_character_set_applicability
# Train on Information Schema: devicetelemetry.information_schema column_column_usage
# Train on Information Schema: devicetelemetry.information_schema column_domain_usage
# Train on Information Schema: devicetelemetry.information_schema column_privileges
# Train on Information Schema: devicetelemetry.information_schema column_udt_usage
# Train on Information Schema: devicetelemetry.information_schema column_options
# Train on Information Schema: devicetelemetry.information_schema constraint_column_usage
# Train on Information Schema: devicetelemetry.information_schema constraint_table_usage
# Train on Information Schema: devicetelemetry.information_schema domain_constraints
# Train on Information Schema: devicetelemetry.information_schema domain_udt_usage
# Train on Information Schema: devicetelemetry.information_schema foreign_data_wrapper_options
# Train on Information Schema: devicetelemetry.information_schema enabled_roles
# Train on Information Schema: devicetelemetry.information_schema foreign_data_wrappers
# Train on Information Schema: devicetelemetry.information_schema referential_constraints
# Train on Information Schema: devicetelemetry.information_schema role_column_grants
# Train on Information Schema: devicetelemetry.information_schema routine_column_usage
# Train on Information Schema: devicetelemetry.information_schema routine_privileges
# Train on Information Schema: devicetelemetry.information_schema role_routine_grants
# Train on Information Schema: devicetelemetry.information_schema routine_routine_usage
# Train on Information Schema: devicetelemetry.information_schema routine_sequence_usage
# Train on Information Schema: devicetelemetry.information_schema routine_table_usage
# Train on Information Schema: devicetelemetry.information_schema foreign_server_options

# %%
# vn.train(plan=plan)

# %%
# vn.ask(question="What are the ID's and battery powers from DeviceTelemetryData")

# %%
vn.generate_queries("Give other question sql pairs.")
# Out:
# Using model gpt-4 for 197.5 tokens (approx)
# 'Sure, here are the queries:\n\n1. \n{\'question\': \'What is the current state of battery recalibration for each device?\', \n\'sql\': \'SELECT "Imei", "BMS_SOCRecalibState" FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}\n\n2. \n{\'question\': \'What is the average internal state of charge (SOC) for each device?\', \n\'sql\': \'SELECT "Imei", AVG("BMS_InternalSOC") AS Average_Internal_SOC FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}\n\n3. \n{\'question\': \'What are the maximum and minimum cell temperatures for each device?\', \n\'sql\': \'SELECT "Imei", MAX("BMS_CellTMax"), MIN("BMS_CellTMin") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}\n\n4. \n{\'question\': \'What is the last modified date for each device?\', \n\'sql\': \'SELECT "Imei", MAX("LastModifiedOn") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}\n\n5. \n{\'question\': \'What is the average latitude and longitude for each device?\', \n\'sql\': \'SELECT "Imei", AVG("Latitude"), AVG("Longitude") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}\n\n6. \n{\'question\': \'What is the maximum battery voltage for each device?\', \n\'sql\': \'SELECT "Imei", MAX("BMS_UBatt") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}\n\n7. \n{\'question\': \'Who was the last person to modify each device?\', \n\'sql\': \'SELECT "Imei", "LastModifiedBy" FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}\n\n8.\n{\'question\': \'What is the difference between the maximum and minimum battery voltage for each device?\',\n \'sql\': \'SELECT "Imei", (MAX("BMS_UBatt") - MIN("BMS_UBatt")) as Voltage_Difference FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";\'}'

# %%
pair_format_1 = {
    "question": "What is the current state of battery recalibration for each device?",
    "sql": 'SELECT "Imei", "BMS_SOCRecalibState" FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

pair_format_2 = {
    "question": "What is the average internal state of charge (SOC) for each device?",
    "sql": 'SELECT "Imei", AVG("BMS_InternalSOC") AS Average_Internal_SOC FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

pair_format_3 = {
    "question": "What are the maximum and minimum cell temperatures for each device?",
    "sql": 'SELECT "Imei", MAX("BMS_CellTMax"), MIN("BMS_CellTMin") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

pair_format_4 = {
    "question": "What is the last modified date for each device?",
    "sql": 'SELECT "Imei", MAX("LastModifiedOn") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

pair_format_5 = {
    "question": "What is the average latitude and longitude for each device?",
    "sql": 'SELECT "Imei", AVG("Latitude"), AVG("Longitude") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

pair_format_6 = {
    "question": "What is the maximum battery voltage for each device?",
    "sql": 'SELECT "Imei", MAX("BMS_UBatt") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

pair_format_7 = {
    "question": "Who was the last person to modify each device?",
    "sql": 'SELECT "Imei", "LastModifiedBy" FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

pair_format_8 = {
    "question": "What is the difference between the maximum and minimum battery voltage for each device?",
    "sql": 'SELECT "Imei", (MAX("BMS_UBatt") - MIN("BMS_UBatt")) as Voltage_Difference FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
}

vn.train(
    question="What is the current state of battery recalibration for each device?",
    sql='SELECT "Imei", "BMS_SOCRecalibState" FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)

vn.train(
    question="What is the average internal state of charge (SOC) for each device?",
    sql='SELECT "Imei", AVG("BMS_InternalSOC") AS Average_Internal_SOC FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)

vn.train(
    question="What are the maximum and minimum cell temperatures for each device?",
    sql='SELECT "Imei", MAX("BMS_CellTMax"), MIN("BMS_CellTMin") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)

vn.train(
    question="What is the last modified date for each device?",
    sql='SELECT "Imei", MAX("LastModifiedOn") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)

vn.train(
    question="What is the average latitude and longitude for each device?",
    sql='SELECT "Imei", AVG("Latitude"), AVG("Longitude") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)

vn.train(
    question="What is the maximum battery voltage for each device?",
    sql='SELECT "Imei", MAX("BMS_UBatt") FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)

vn.train(
    question="Who was the last person to modify each device?",
    sql='SELECT "Imei", "LastModifiedBy" FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)

vn.train(
    question="What is the difference between the maximum and minimum battery voltage for each device?",
    sql='SELECT "Imei", (MAX("BMS_UBatt") - MIN("BMS_UBatt")) as Voltage_Difference FROM "Catalog"."DeviceTelemetryData" GROUP BY "Imei";'
)
# Out:
# 'c6208aa8-cbb4-551a-b258-953529283da5-sql'

# %%
from vanna.flask import VannaFlaskApp
app = VannaFlaskApp(vn, allow_llm_to_see_data=True)
app.run()
# Out:
# Your app is running at:
# http://localhost:8084
#  * Serving Flask app 'vanna.flask'
#  * Debug mode: on
# Using model gpt-4 for 4286.5 tokens (approx)
# Using model gpt-4 for 133.5 tokens (approx)
# Using model gpt-4 for 4286.5 tokens (approx)
